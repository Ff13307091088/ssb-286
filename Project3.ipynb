# %% [markdown]
# #  Executive Summary

# %% [markdown]
# * There is a strong coefficient correlation between owner_First and owner_Second. We guess that people paying the first-hand car is unlikely to buy the second-hand car, due to their wealth or mysophobia. But in contract, people buying the second or more hand-car would not care so much. So those independent factors (the second or more-hand car) don’t have strong coefficient correlation.
# *

# %% [markdown]
# # Feature Engineering

# %%
# import the library that I need
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import math
from sklearn.metrics import mean_squared_error
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('cars_india.csv')
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df['make']=df.name.str.split().str[0] # split the name by their first name
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats     make
# 0            190Nm@ 2000rpm    5.0   Maruti
# 1       250Nm@ 1500-2500rpm    5.0    Skoda
# 2     12.7@ 2,700(kgm@ rpm)    5.0    Honda
# 3  22.4 kgm at 1750-2750rpm    5.0  Hyundai
# 4     11.5@ 4,500(kgm@ rpm)    5.0   Maruti

# %%
df['unite_mileage'] = df.mileage.str.split().str[-1]
df.groupby('unite_mileage').size() # to make sure that the unite of mileage is the same
# Out:
# unite_mileage
# km/kg      88
# kmpl     7819
# dtype: int64

# %%
df['n_mileage'] = df.mileage.str.split().str[0]

# %%
df['unite_engine'] = df.engine.str.split().str[-1]
df.groupby('unite_engine').size() # to make sure that the units of engine is the same
# Out:
# unite_engine
# CC    7907
# dtype: int64

# %%
df['n_engine'] = df.engine.str.split().str[0]

# %%
df['unite_max_power'] = df.max_power.str.split().str[-1]
df.groupby('unite_max_power').size() # to make sure that the units of max_power is the same
# Out:
# unite_max_power
# 0         6
# bhp    7907
# dtype: int64

# %%
df['n_max_power'] = df.max_power.str.split().str[0]

# %%
df['dollars'] = df['selling_price']*0.013 # rupees to US dollars using the current conversion rates.
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   ...    \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC   ...
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC   ...
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC   ...
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC   ...
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC   ...
#
#                      torque seats     make unite_mileage n_mileage  \
# 0            190Nm@ 2000rpm   5.0   Maruti          kmpl      23.4
# 1       250Nm@ 1500-2500rpm   5.0    Skoda          kmpl     21.14
# 2     12.7@ 2,700(kgm@ rpm)   5.0    Honda          kmpl      17.7
# 3  22.4 kgm at 1750-2750rpm   5.0  Hyundai          kmpl      23.0
# 4     11.5@ 4,500(kgm@ rpm)   5.0   Maruti          kmpl      16.1
#
#   unite_engine n_engine unite_max_power n_max_power dollars
# 0           CC     1248             bhp          74  5850.0
# 1           CC     1498             bhp      103.52  4810.0
# 2           CC     1497             bhp          78  2054.0
# 3           CC     1396             bhp          90  2925.0
# 4           CC     1298             bhp        88.2  1690.0
#
# [5 rows x 21 columns]

# %%
df['m_driven'] = df['km_driven'] *1000 # km driven to miles driven
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine    ...      \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC    ...
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC    ...
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC    ...
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC    ...
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    ...
#
#   seats     make  unite_mileage n_mileage unite_engine n_engine  \
# 0   5.0   Maruti           kmpl      23.4           CC     1248
# 1   5.0    Skoda           kmpl     21.14           CC     1498
# 2   5.0    Honda           kmpl      17.7           CC     1497
# 3   5.0  Hyundai           kmpl      23.0           CC     1396
# 4   5.0   Maruti           kmpl      16.1           CC     1298
#
#   unite_max_power n_max_power dollars   m_driven
# 0             bhp          74  5850.0  145500000
# 1             bhp      103.52  4810.0  120000000
# 2             bhp          78  2054.0  140000000
# 3             bhp          90  2925.0  127000000
# 4             bhp        88.2  1690.0  120000000
#
# [5 rows x 22 columns]

# %%
df.n_mileage.isna().count() # so there is null row, we can not just directly time a value
# Out:
# 8128

# %%
def mpg(n):
    if pd.isna(n) == False:
        z = float(n)*2.353
    else:
        z = n
    return z # def a function that would keep the original data if it null, else times 2.353
df['mpg'] = df.apply(lambda row: mpg(row['n_mileage']), axis = 1)
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine    ...     \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC    ...
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC    ...
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC    ...
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC    ...
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    ...
#
#       make unite_mileage  n_mileage unite_engine n_engine unite_max_power  \
# 0   Maruti          kmpl       23.4           CC     1248             bhp
# 1    Skoda          kmpl      21.14           CC     1498             bhp
# 2    Honda          kmpl       17.7           CC     1497             bhp
# 3  Hyundai          kmpl       23.0           CC     1396             bhp
# 4   Maruti          kmpl       16.1           CC     1298             bhp
#
#   n_max_power dollars   m_driven       mpg
# 0          74  5850.0  145500000  55.06020
# 1      103.52  4810.0  120000000  49.74242
# 2          78  2054.0  140000000  41.64810
# 3          90  2925.0  127000000  54.11900
# 4        88.2  1690.0  120000000  37.88330
#
# [5 rows x 23 columns]

# %%
df2 = df.copy()
df2 = pd.get_dummies(df2,columns =["transmission", 'owner', 'seller_type', 'fuel'])
df2.head()
# Out:
#                            name  year  selling_price  km_driven     mileage  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500   23.4 kmpl
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  21.14 kmpl
# 2      Honda City 2017-2020 EXi  2006         158000     140000   17.7 kmpl
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000   23.0 kmpl
# 4        Maruti Swift VXI BSIII  2007         130000     120000   16.1 kmpl
#
#     engine   max_power                    torque  seats     make     ...       \
# 0  1248 CC      74 bhp            190Nm@ 2000rpm    5.0   Maruti     ...
# 1  1498 CC  103.52 bhp       250Nm@ 1500-2500rpm    5.0    Skoda     ...
# 2  1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)    5.0    Honda     ...
# 3  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm    5.0  Hyundai     ...
# 4  1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)    5.0   Maruti     ...
#
#   owner_Second Owner owner_Test Drive Car owner_Third Owner  \
# 0                  0                    0                 0
# 1                  1                    0                 0
# 2                  0                    0                 1
# 3                  0                    0                 0
# 4                  0                    0                 0
#
#   seller_type_Dealer seller_type_Individual seller_type_Trustmark Dealer  \
# 0                  0                      1                            0
# 1                  0                      1                            0
# 2                  0                      1                            0
# 3                  0                      1                            0
# 4                  0                      1                            0
#
#    fuel_CNG  fuel_Diesel  fuel_LPG  fuel_Petrol
# 0         0            1         0            0
# 1         0            1         0            0
# 2         0            0         0            1
# 3         0            1         0            0
# 4         0            0         0            1
#
# [5 rows x 33 columns]

# %%
df.year.min() # get the lowest year
# Out:
# 1983

# %%
df2['time'] = df.year - 1983

# %%
df2['Honda'] = 0
df2.loc[df2['make'] == 'Honda',['Honda']] = 1

# %%
df2.drop(['torque','mileage','selling_price','km_driven','max_power','name','year',\
         'unite_max_power','unite_mileage','unite_engine'],axis=1,inplace = True)
df2.head()
# Out:
#     engine  seats     make n_mileage n_engine n_max_power  dollars   m_driven  \
# 0  1248 CC    5.0   Maruti      23.4     1248          74   5850.0  145500000
# 1  1498 CC    5.0    Skoda     21.14     1498      103.52   4810.0  120000000
# 2  1497 CC    5.0    Honda      17.7     1497          78   2054.0  140000000
# 3  1396 CC    5.0  Hyundai      23.0     1396          90   2925.0  127000000
# 4  1298 CC    5.0   Maruti      16.1     1298        88.2   1690.0  120000000
#
#         mpg  transmission_Automatic  ...    owner_Third Owner  \
# 0  55.06020                       0  ...                    0
# 1  49.74242                       0  ...                    0
# 2  41.64810                       0  ...                    1
# 3  54.11900                       0  ...                    0
# 4  37.88330                       0  ...                    0
#
#    seller_type_Dealer  seller_type_Individual  seller_type_Trustmark Dealer  \
# 0                   0                       1                             0
# 1                   0                       1                             0
# 2                   0                       1                             0
# 3                   0                       1                             0
# 4                   0                       1                             0
#
#    fuel_CNG  fuel_Diesel  fuel_LPG  fuel_Petrol  time  Honda
# 0         0            1         0            0    31      0
# 1         0            1         0            0    31      0
# 2         0            0         0            1    23      1
# 3         0            1         0            0    27      0
# 4         0            0         0            1    24      0
#
# [5 rows x 25 columns]

# %%
df2.isna().count() # check all the columns
# Out:
# engine                          8128
# seats                           8128
# make                            8128
# n_mileage                       8128
# n_engine                        8128
# n_max_power                     8128
# dollars                         8128
# m_driven                        8128
# mpg                             8128
# transmission_Automatic          8128
# transmission_Manual             8128
# owner_First Owner               8128
# owner_Fourth & Above Owner      8128
# owner_Second Owner              8128
# owner_Test Drive Car            8128
# owner_Third Owner               8128
# seller_type_Dealer              8128
# seller_type_Individual          8128
# seller_type_Trustmark Dealer    8128
# fuel_CNG                        8128
# fuel_Diesel                     8128
# fuel_LPG                        8128
# fuel_Petrol                     8128
# time                            8128
# Honda                           8128
# dtype: int64

# %% [markdown]
# # Regression

# %%
X = df2[['Honda','m_driven','fuel_Diesel','fuel_Petrol','fuel_CNG','fuel_LPG','owner_Second Owner',\
         'owner_Third Owner','owner_Fourth & Above Owner']].copy()
Y = df2['dollars'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.5, random_state = 2)

# %%
X_train = sm.add_constant(X_train) # required if constant expected
est = sm.OLS(y_train,X_train).fit() # fit model
predictions = est.predict() # get predicted values
print(est.summary()) # prints full regression results
print("\nAverage error: {:.2f}.".format(math.sqrt(est.mse_resid)))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                dollars   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     102.6
# Date:                Tue, 17 Nov 2020   Prob (F-statistic):          3.38e-156
# Time:                        15:39:14   Log-Likelihood:                -43108.
# No. Observations:                4064   AIC:                         8.623e+04
# Df Residuals:                    4055   BIC:                         8.629e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       9004.0087    596.035     15.106      0.000    7835.452    1.02e+04
# Honda                       -148.6484    663.222     -0.224      0.823   -1448.928    1151.631
# m_driven                   -5.354e-05   3.19e-06    -16.799      0.000   -5.98e-05   -4.73e-05
# fuel_Diesel                 7222.3564    593.552     12.168      0.000    6058.669    8386.044
# fuel_Petrol                 1267.2857    595.837      2.127      0.033      99.119    2435.453
# fuel_CNG                     177.1893   1566.467      0.113      0.910   -2893.947    3248.325
# fuel_LPG                     337.1773   1716.638      0.196      0.844   -3028.375    3702.730
# owner_Second Owner         -3923.6225    367.087    -10.689      0.000   -4643.315   -3203.930
# owner_Third Owner          -4571.3122    637.014     -7.176      0.000   -5820.210   -3322.415
# owner_Fourth & Above Owner -4412.2367   1048.248     -4.209      0.000   -6467.379   -2357.095
# ==============================================================================
# Omnibus:                     3645.460   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           114195.757
# Skew:                           4.338   Prob(JB):                         0.00
# Kurtosis:                      27.476   Cond. No.                     1.12e+24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.48e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Average error: 9793.79.

# %%
X_test = sm.add_constant(X_test) # required if constant expected
est = sm.OLS(y_test,X_test).fit() # fit model
predictions = est.predict() # get predicted values
print(est.summary()) # prints full regression results
print("\nAverage error: {:.2f}.".format(math.sqrt(est.mse_resid)))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                dollars   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     92.05
# Date:                Tue, 17 Nov 2020   Prob (F-statistic):          5.89e-141
# Time:                        15:39:14   Log-Likelihood:                -42950.
# No. Observations:                4064   AIC:                         8.592e+04
# Df Residuals:                    4055   BIC:                         8.597e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       8250.4589    609.475     13.537      0.000    7055.553    9445.364
# Honda                        302.8972    644.308      0.470      0.638    -960.300    1566.095
# m_driven                   -3.818e-05   2.68e-06    -14.250      0.000   -4.34e-05   -3.29e-05
# fuel_Diesel                 6727.2170    610.698     11.016      0.000    5529.914    7924.520
# fuel_Petrol                 1043.5656    612.344      1.704      0.088    -156.965    2244.096
# fuel_CNG                      20.8947   1456.152      0.014      0.989   -2833.963    2875.752
# fuel_LPG                     458.7815   1920.025      0.239      0.811   -3305.521    4223.084
# owner_Second Owner         -3930.0278    357.505    -10.993      0.000   -4630.935   -3229.121
# owner_Third Owner          -4447.0885    602.254     -7.384      0.000   -5627.838   -3266.339
# owner_Fourth & Above Owner -5368.7386   1070.117     -5.017      0.000   -7466.756   -3270.721
# ==============================================================================
# Omnibus:                     3551.540   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94720.748
# Skew:                           4.233   Prob(JB):                         0.00
# Kurtosis:                      25.084   Cond. No.                     8.13e+23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.2e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Average error: 9419.65.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

variables = est.model.exog # get model features
vif = pd.DataFrame() # create a dataframe
vif["VIF Factor"] = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif["features"] = X_test.columns
print('VIF: {}'.format(vif))
# Out:
# VIF:    VIF Factor                    features
# 0    0.000000                       const
# 1    1.019329                       Honda
# 2    1.175893                    m_driven
# 3         inf                 fuel_Diesel
# 4         inf                 fuel_Petrol
# 5         inf                    fuel_CNG
# 6         inf                    fuel_LPG
# 7    1.102640          owner_Second Owner
# 8    1.072772           owner_Third Owner
# 9    1.024553  owner_Fourth & Above Owner
# /Users/mac/opt/anaconda3/envs/MISY408/lib/python3.5/site-packages/statsmodels/regression/linear_model.py:1543: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /Users/mac/opt/anaconda3/envs/MISY408/lib/python3.5/site-packages/statsmodels/stats/outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
corr = X_test.corr()
corr.style.background_gradient()
# Out:
# /Users/mac/opt/anaconda3/envs/MISY408/lib/python3.5/site-packages/matplotlib/colors.py:496: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col0 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col3 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col8 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row0_col9 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col1 {
#             background-color:  #023858;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col2 {
#             background-color:  #e0dded;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col3 {
#             background-color:  #8eb3d5;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col4 {
#             background-color:  #589ec8;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col5 {
#             background-color:  #f5eff6;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col6 {
#             background-color:  #f8f1f8;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col7 {
#             background-color:  #f0eaf4;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col8 {
#             background-color:  #e6e2ef;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row1_col9 {
#             background-color:  #f8f1f8;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col0 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col1 {
#             background-color:  #f4edf6;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col2 {
#             background-color:  #023858;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col3 {
#             background-color:  #358fc0;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col4 {
#             background-color:  #abbfdc;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col5 {
#             background-color:  #f4edf6;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col6 {
#             background-color:  #f2ecf5;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col7 {
#             background-color:  #bcc7e1;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col8 {
#             background-color:  #cacee5;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row2_col9 {
#             background-color:  #e7e3f0;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col0 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col1 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col2 {
#             background-color:  #97b7d7;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col3 {
#             background-color:  #023858;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col4 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col5 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col6 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col7 {
#             background-color:  #e3e0ee;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col8 {
#             background-color:  #e8e4f0;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row3_col9 {
#             background-color:  #f3edf5;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col0 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col1 {
#             background-color:  #d8d7e9;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col3 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col4 {
#             background-color:  #023858;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col5 {
#             background-color:  #fdf5fa;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col6 {
#             background-color:  #fef6fa;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col7 {
#             background-color:  #f0eaf4;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col8 {
#             background-color:  #ebe6f2;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row4_col9 {
#             background-color:  #f4eef6;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col0 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col1 {
#             background-color:  #f2ecf5;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col2 {
#             background-color:  #dbdaeb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col3 {
#             background-color:  #89b1d4;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col4 {
#             background-color:  #86b0d3;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col5 {
#             background-color:  #023858;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col6 {
#             background-color:  #f6eff7;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col7 {
#             background-color:  #e5e1ef;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col8 {
#             background-color:  #ece7f2;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row5_col9 {
#             background-color:  #f2ecf5;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col0 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col1 {
#             background-color:  #f1ebf5;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col2 {
#             background-color:  #d7d6e9;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col3 {
#             background-color:  #84b0d3;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col4 {
#             background-color:  #81aed2;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col5 {
#             background-color:  #f3edf5;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col6 {
#             background-color:  #023858;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col7 {
#             background-color:  #e3e0ee;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col8 {
#             background-color:  #e4e1ef;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row6_col9 {
#             background-color:  #f5eef6;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row7_col0 {
#             background-color:  #fff7fb;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row7_col1 {
#             background-color:  #f5eef6;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row7_col2 {
#             background-color:  #a9bfdc;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row7_col3 {
#             background-color:  #6fa7ce;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row7_col4 {
#             background-color:  #7eadd1;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row7_col5 {
#             background-color:  #efe9f3;
#         }    #T_f4f61606_2914_11eb_ad65_8218335aa600row7_col6 {
#             bac
